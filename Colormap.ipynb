# %% [markdown]
# <a href="https://colab.research.google.com/github/3-bdur/20221CCS0061-Abdur-Rehman-Ahmed/blob/main/Colormap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.DataFrame({
    "x":np.random.randn(100),
    "y":np.random.randn(100),
    "value":np.random.randn(100),
})
cmap="magma"
alpha=1

plt.figure(figsize=(6,6))
plt.scatter(data["x"],data["y"],c=data["value"],cmap=cmap,alpha=alpha)

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatterplot with colormap")
plt.colorbar(label="value")
plt.show()

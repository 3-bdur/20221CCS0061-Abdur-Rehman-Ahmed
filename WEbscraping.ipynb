# %% [markdown]
# <a href="https://colab.research.google.com/github/3-bdur/20221CCS0061-Abdur-Rehman-Ahmed/blob/main/WEbscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
Link="https://www.formula1.com/en/results.html/2024/drivers.html"
Link_text=requests.get(Link).text
print(Link_text)

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(Link_text,'lxml')

# %%
print(soup.prettify())

# %%
print(soup.title)

# %%
print(soup.title.string)
# Out:
#     2024 Driver Standings

# %%
soup.a
# Out:
# <a class="skip" href="#globalNav" tabindex="1">Skip to Global Nav</a>

# %%
soup.find_all('a')

# %%
all_table=soup.find_all('table')

# %%
print(all_table)

# %%
table=soup.find('table',{'class':'resultsarchive-table'})

# %%
thead=table.find('thead')

# %%
headers=[th.text.strip() for th in thead.find_all('th')]

# %%
tbody =table.find('tbody')
rows=[]
for tr in tbody.find_all('tr'):
    data=[td.text.strip() for td in tr.find_all('td')]
    rows.append(data)

# %%
import pandas as pd

# %%
df=pd.read_html(str(table))[0]
print(df)
# Out:
#     Unnamed: 0  Pos                Driver Nationality  \
# 0          NaN    1    Max Verstappen VER         NED
# 1          NaN    2      Sergio Perez PER         MEX
# 2          NaN    3   Charles Leclerc LEC         MON
# 3          NaN    4    George Russell RUS         GBR
# 4          NaN    5     Oscar Piastri PIA         AUS
# 5          NaN    6      Carlos Sainz SAI         ESP
# 6          NaN    7   Fernando Alonso ALO         ESP
# 7          NaN    8      Lando Norris NOR         GBR
# 8          NaN    9    Lewis Hamilton HAM         GBR
# 9          NaN   10    Oliver Bearman BEA         GBR
# 10         NaN   11   Nico Hulkenberg HUL         GER
# 11         NaN   12      Lance Stroll STR         CAN
# 12         NaN   13   Alexander Albon ALB         THA
# 13         NaN   14       Zhou Guanyu ZHO         CHN
# 14         NaN   15   Kevin Magnussen MAG         DEN
# 15         NaN   16  Daniel Ricciardo RIC         AUS
# ...

# %%
df.set_index('Pos',inplace=True)
df.head()
# Out:
#      Unnamed: 0               Driver Nationality                         Car  \
# Pos
# 1           NaN   Max Verstappen VER         NED  Red Bull Racing Honda RBPT
# 2           NaN     Sergio Perez PER         MEX  Red Bull Racing Honda RBPT
# 3           NaN  Charles Leclerc LEC         MON                     Ferrari
# 4           NaN   George Russell RUS         GBR                    Mercedes
# 5           NaN    Oscar Piastri PIA         AUS            McLaren Mercedes
#
#      PTS  Unnamed: 6
# Pos
# 1     51         NaN
# 2     36         NaN
# 3     28         NaN
# 4     18         NaN
# 5     16         NaN

# %%
df=df.drop(columns=['Unnamed: 0','Unnamed: 6'])

# %%
df.head()
# Out:
#                   Driver Nationality                         Car  PTS
# Pos
# 1     Max Verstappen VER         NED  Red Bull Racing Honda RBPT   51
# 2       Sergio Perez PER         MEX  Red Bull Racing Honda RBPT   36
# 3    Charles Leclerc LEC         MON                     Ferrari   28
# 4     George Russell RUS         GBR                    Mercedes   18
# 5      Oscar Piastri PIA         AUS            McLaren Mercedes   16

# %%
images = soup.find_all('img')
for img in images:
    src = img.get('src')
    print(src)
# Out:
# /etc/designs/fom-website/images/f1_logo_red.svg
# /etc/designs/fom-website/images/f1_logo.svg
# /etc/designs/fom-website/images/f1_logo.svg
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /etc/designs/fom-website/images/fia_logo.png
# /etc/designs/fom-website/images/f1-tv-logo.svg
# /etc/designs/fom-website/images/f1-tv-logo.svg
# /etc/designs/fom-website/images/f2_logo.png
# /etc/designs/fom-website/images/f3_logo.png
# /etc/designs/fom-website/images/f1academy.svg
# /etc/designs/fom-website/images/event-tracker/circuit.svg
# /etc/designs/fom-website/images/event-tracker/circuit.svg
# /etc/designs/fom-website/images/event-tracker/spinner.svg
# /etc/designs/fom-website/images/event-tracker/spinner.svg
# /etc/designs/fom-website/images/f1_logo.svg
# /etc/designs/fom-website/images/event-tracker/circuit.svg
# /etc/designs/fom-website/images/event-tracker/circuit.svg
# /etc/designs/fom-website/images/event-tracker/circuit.svg
# ...

# %%
import re
import json
